# %%
# !jupyter nbextension enable --py widgetsnbextension
# Out:
# Enabling notebook extension jupyter-js-widgets/extension...
#       - Validating: OK

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
import torch
from transformers import pipeline
from transformers.pipelines.pt_utils import Dataset, KeyDataset
import time
from tqdm.auto import tqdm

# %%
class ListDataset(Dataset):
    def __init__(self, original_list):
        self.original_list = original_list

    def __len__(self):
        return len(self.original_list)
    
    def __getitem__(self, i):
        return self.original_list[i]

# %%
#I modified this code quite a bit, now it only returns date and tweet text (preprocessed). username and language are excluded
def run_sentiment_analysis_and_save(path_to_tweets, model_path = f"cardiffnlp/twitter-roberta-base-sentiment-latest"):
    input_csv = pd.read_csv(path_to_tweets) 
    input_csv.head()
    tweet_text = input_csv['text'].to_list()
    #this dataframe column should be changed for question 1 and 2 to "tweetcreatedts" and for question 3 "Date"
    tweet_date = input_csv['Date'].to_list()  
    filtered_tweets = [] # If some tweets have no text for whatever reason, we remove them
    filtered_dates = []
    for i in range(len(tweet_text)):
        if type(tweet_text[i]) == str:
            filtered_tweets.append(tweet_text[i])
            filtered_dates.append(tweet_date[i])
    print('Removed ', len(tweet_text) - len(filtered_tweets), 'invalid tweets')
    

    #Adding a preprocessing step to remove links and users
    pre_processed = [] #we put all the filtered tweets in this array
    for tweet in filtered_tweets:
        tweet_words = [] 
        for word in tweet.split(' '):
            if word.startswith('@') and len(word) > 1: #if it is a mention then it starts with @ 
                word = '@user'
            elif "http" in word:
                i = word.index("http")
                word = word[:i] + "http"
            #    word = "http"
            tweet_words.append(word)
        tweet = " ".join(tweet_words)
        pre_processed.append(tweet)

    


    # print(tweet_text[:10])
    # tweets_dataset = ListDataset(tweet_text)
    print('Loaded tweets at ' + path_to_tweets)

    sentiment_pipeline = pipeline("sentiment-analysis", model=model_path, tokenizer=model_path, max_length=512, truncation=True)
    
    print('Running Sentiment Analysis...')
    start_time = time.time()
    result = sentiment_pipeline(pre_processed)
    end_time = time.time()
    print('Time elapsed: ', end_time - start_time, ' seconds')

    #added by Sheikh, feel free to fix if you find any issue
    data_given = {"Date": filtered_dates, "text": pre_processed}
    data_given = pd.DataFrame(data_given)
    result = pd.DataFrame(result)
    result_df = data_given.join(result)
    result_df.to_csv(path_to_tweets.split('.csv')[0] + '_with_sentiment.csv')
    #data_given.to_csv(path_to_tweets.split('.csv')[0] + 'test_preprocessing.csv')
    return data_given

# %% [markdown]
# ## Q1

# %%
q1_path = '../DataCollection/scrapping/output/q1/all_tweets.csv'
run_sentiment_analysis_and_save(q1_path)
# Out:
# Removed  1 invalid tweets
# Loaded tweets at ../DataCollection/scrapping/output/q1/all_tweets.csv
# Some weights of the model checkpoint at cardiffnlp/twitter-roberta-base-sentiment-latest were not used when initializing RobertaForSequenceClassification: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Running Sentiment Analysis...
# Time elapsed:  2803.428108215332  seconds
#                             Date  \
# 0      2021-12-24 23:57:40+00:00
# 1      2021-12-24 23:57:27+00:00
# 2      2021-12-24 23:57:25+00:00
# 3      2021-12-24 23:55:36+00:00
# 4      2021-12-24 23:55:16+00:00
# ...                          ...
# 75204  2022-05-23 22:58:29+00:00
# 75205  2022-05-23 22:58:27+00:00
# 75206  2022-05-23 22:58:22+00:00
# 75207  2022-05-23 22:58:21+00:00
# 75208  2022-05-23 22:58:19+00:00
#
#                                                     text
# 0      @user Ukraine is a liability for both Russia a...
# 1      .... because the world must show that Russia’s...
# 2      Russia should be stopped in Ukraine &amp; Ukra...
# 3      @user The Russia-connected sources I read expr...
# 4      @user @user @user @user @user @user @user @use...
# ...                                                  ...
# 75204  @user Why? Why should they? give it another fe...
# 75205  @user Root of inflation is energy and food pri...
# 75206  @user Ukraine is not Iraq. This piece was oppo...
# 75207  The US was defeated by the Taliban. It has no ...
# 75208  @user The very fact that Ukraine is telling yo...
#
# [75209 rows x 2 columns]

# %% [markdown]
# ## Q2

# %% [markdown]
# ### English

# %%
q2_path_1 = '../DataCollection/scrapping/output/q2/nato_english.csv'
run_sentiment_analysis_and_save(q2_path_1)
# Out:
# Removed  0 invalid tweets
# Loaded tweets at ../DataCollection/scrapping/output/q2/nato_english.csv
# Some weights of the model checkpoint at cardiffnlp/twitter-roberta-base-sentiment-latest were not used when initializing RobertaForSequenceClassification: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/Bensas/ITBA/Intercambios/KAIST/Data Science Methodology/UkraineConflictOnTwitter/SentimentAnalysis/TwitterSentimentAnalysis.ipynb Cell 11' in <cell line: 2>()
#       <a href='vscode-notebook-cell:/Users/Bensas/ITBA/Intercambios/KAIST/Data%20Science%20Methodology/UkraineConflictOnTwitter/SentimentAnalysis/TwitterSentimentAnalysis.ipynb#ch0000011?line=0'>1</a> q2_path_1 = '../DataCollection/scrapping/output/q2/nato_english.csv'
# ----> <a href='vscode-notebook-cell:/Users/Bensas/ITBA/Intercambios/KAIST/Data%20Science%20Methodology/UkraineConflictOnTwitter/SentimentAnalysis/TwitterSentimentAnalysis.ipynb#ch0000011?line=1'>2</a> run_sentiment_analysis_and_save(q2_path_1)
#
# /Users/Bensas/ITBA/Intercambios/KAIST/Data Science Methodology/UkraineConflictOnTwitter/SentimentAnalysis/TwitterSentimentAnalysis.ipynb Cell 6' in run_sentiment_analysis_and_save(path_to_tweets, model_path)
#      <a href='vscode-notebook-cell:/Users/Bensas/ITBA/Intercambios/KAIST/Data%20Science%20Methodology/UkraineConflictOnTwitter/SentimentAnalysis/TwitterSentimentAnalysis.ipynb#ch0000005?line=34'>35</a> # print(tweet_text[:10])
#      <a href='vscode-notebook-cell:/Users/Bensas/ITBA/Intercambios/KAIST/Data%20Science%20Methodology/UkraineConflictOnTwitter/SentimentAnalysis/TwitterSentimentAnalysis.ipynb#ch0000005?line=35'>36</a> # tweets_dataset = ListDataset(tweet_text)
#      <a href='vscode-notebook-cell:/Users/Bensas/ITBA/Intercambios/KAIST/Data%20Science%20Methodology/UkraineConflictOnTwitter/SentimentAnalysis/TwitterSentimentAnalysis.ipynb#ch0000005?line=36'>37</a> print('Loaded tweets at ' + path_to_tweets)
# ---> <a href='vscode-notebook-cell:/Users/Bensas/ITBA/Intercambios/KAIST/Data%20Science%20Methodology/UkraineConflictOnTwitter/SentimentAnalysis/TwitterSentimentAnalysis.ipynb#ch0000005?line=38'>39</a> sentiment_pipeline = pipeline("sentiment-analysis", model=model_path, tokenizer=model_path, max_length=512, truncation=True)
#      <a href='vscode-notebook-cell:/Users/Bensas/ITBA/Intercambios/KAIST/Data%20Science%20Methodology/UkraineConflictOnTwitter/SentimentAnalysis/TwitterSentimentAnalysis.ipynb#ch0000005?line=40'>41</a> print('Running Sentiment Analysis...')
#      <a href='vscode-notebook-cell:/Users/Bensas/ITBA/Intercambios/KAIST/Data%20Science%20Methodology/UkraineConflictOnTwitter/SentimentAnalysis/TwitterSentimentAnalysis.ipynb#ch0000005?line=41'>42</a> start_time = time.time()
#
# File ~/miniforge3/envs/mlp/lib/python3.8/site-packages/transformers/pipelines/__init__.py:598, in pipeline(task, model, config, tokenizer, feature_extractor, framework, revision, use_fast, use_auth_token, model_kwargs, pipeline_class, **kwargs)
#     <a href='file:///Users/Bensas/miniforge3/envs/mlp/lib/python3.8/site-packages/transformers/pipelines/__init__.py?line=594'>595</a>             tokenizer_identifier = tokenizer
#     <a href='file:///Users/Bensas/miniforge3/envs/mlp/lib/python3.8/site-packages/transformers/pipelines/__init__.py?line=595'>596</a>             tokenizer_kwargs = model_kwargs
# --> <a href='file:///Users/Bensas/miniforge3/envs/mlp/lib/python3.8/site-packages/transformers/pipelines/__init__.py?line=597'>598</a>         tokenizer = AutoTokenizer.from_pretrained(
#     <a href='file:///Users/Bensas/miniforge3/envs/mlp/lib/python3.8/site-packages/transformers/pipelines/__init__.py?line=598'>599</a>             tokenizer_identifier, revision=revision, use_fast=use_fast, _from_pipeline=task, **tokenizer_kwargs
#     <a href='file:///Users/Bensas/miniforge3/envs/mlp/lib/python3.8/site-packages/transformers/pipelines/__init__.py?line=599'>600</a>         )
#     <a href='file:///Users/Bensas/miniforge3/envs/mlp/lib/python3.8/site-packages/transformers/pipelines/__init__.py?line=601'>602</a> if load_feature_extractor:
#     <a href='file:///Users/Bensas/miniforge3/envs/mlp/lib/python3.8/site-packages/transformers/pipelines/__init__.py?line=602'>603</a>     # Try to infer feature extractor from model or config name (if provided as str)
#     <a href='file:///Users/Bensas/miniforge3/envs/mlp/lib/python3.8/site-packages/transformers/pipelines/__init__.py?line=603'>604</a>     if feature_extractor is None:
#
# File ~/miniforge3/envs/mlp/lib/python3.8/site-packages/transformers/models/auto/tokenization_auto.py:471, in AutoTokenizer.from_pretrained(cls, pretrained_model_name_or_path, *inputs, **kwargs)
#     <a href='file:///Users/Bensas/miniforge3/envs/mlp/lib/python3.8/site-packages/transformers/models/auto/tokenization_auto.py?line=467'>468</a>     return tokenizer_class.from_pretrained(pretrained_model_name_or_path, *inputs, **kwargs)
#     <a href='file:///Users/Bensas/miniforge3/envs/mlp/lib/python3.8/site-packages/transformers/models/auto/tokenization_auto.py?line=469'>470</a> # Next, let's try to use the tokenizer_config file to get the tokenizer class.
# --> <a href='file:///Users/Bensas/miniforge3/envs/mlp/lib/python3.8/site-packages/transformers/models/auto/tokenization_auto.py?line=470'>471</a> tokenizer_config = get_tokenizer_config(pretrained_model_name_or_path, **kwargs)
#     <a href='file:///Users/Bensas/miniforge3/envs/mlp/lib/python3.8/site-packages/transformers/models/auto/tokenization_auto.py?line=471'>472</a> config_tokenizer_class = tokenizer_config.get("tokenizer_class")
#     <a href='file:///Users/Bensas/miniforge3/envs/mlp/lib/python3.8/site-packages/transformers/models/auto/tokenization_auto.py?line=472'>473</a> tokenizer_auto_map = None
#
# File ~/miniforge3/envs/mlp/lib/python3.8/site-packages/transformers/models/auto/tokenization_auto.py:332, in get_tokenizer_config(pretrained_model_name_or_path, cache_dir, force_download, resume_download, proxies, use_auth_token, revision, local_files_only, **kwargs)
#     <a href='file:///Users/Bensas/miniforge3/envs/mlp/lib/python3.8/site-packages/transformers/models/auto/tokenization_auto.py?line=262'>263</a> def get_tokenizer_config(
#     <a href='file:///Users/Bensas/miniforge3/envs/mlp/lib/python3.8/site-packages/transformers/models/auto/tokenization_auto.py?line=263'>264</a>     pretrained_model_name_or_path: Union[str, os.PathLike],
#     <a href='file:///Users/Bensas/miniforge3/envs/mlp/lib/python3.8/site-packages/transformers/models/auto/tokenization_auto.py?line=264'>265</a>     cache_dir: Optional[Union[str, os.PathLike]] = None,
#    (...)
#     <a href='file:///Users/Bensas/miniforge3/envs/mlp/lib/python3.8/site-packages/transformers/models/auto/tokenization_auto.py?line=271'>272</a>     **kwargs,
#     <a href='file:///Users/Bensas/miniforge3/envs/mlp/lib/python3.8/site-packages/transformers/models/auto/tokenization_auto.py?line=272'>273</a> ):
#     <a href='file:///Users/Bensas/miniforge3/envs/mlp/lib/python3.8/site-packages/transformers/models/auto/tokenization_auto.py?line=273'>274</a>     """
#     <a href='file:///Users/Bensas/miniforge3/envs/mlp/lib/python3.8/site-packages/transformers/models/auto/tokenization_auto.py?line=274'>275</a>     Loads the tokenizer configuration from a pretrained model tokenizer configuration.
#     <a href='file:///Users/Bensas/miniforge3/envs/mlp/lib/python3.8/site-packages/transformers/models/auto/tokenization_auto.py?line=275'>276</a>
#    (...)
#     <a href='file:///Users/Bensas/miniforge3/envs/mlp/lib/python3.8/site-packages/transformers/models/auto/tokenization_auto.py?line=329'>330</a>     tokenizer_config = get_tokenizer_config("tokenizer-test")
#     <a href='file:///Users/Bensas/miniforge3/envs/mlp/lib/python3.8/site-packages/transformers/models/auto/tokenization_auto.py?line=330'>331</a>     ```"""
# --> <a href='file:///Users/Bensas/miniforge3/envs/mlp/lib/python3.8/site-packages/transformers/models/auto/tokenization_auto.py?line=331'>332</a>     resolved_config_file = get_file_from_repo(
#     <a href='file:///Users/Bensas/miniforge3/envs/mlp/lib/python3.8/site-packages/transformers/models/auto/tokenization_auto.py?line=332'>333</a>         pretrained_model_name_or_path,
#     <a href='file:///Users/Bensas/miniforge3/envs/mlp/lib/python3.8/site-packages/transformers/models/auto/tokenization_auto.py?line=333'>334</a>         TOKENIZER_CONFIG_FILE,
#     <a href='file:///Users/Bensas/miniforge3/envs/mlp/lib/python3.8/site-packages/transformers/models/auto/tokenization_auto.py?line=334'>335</a>         cache_dir=cache_dir,
#     <a href='file:///Users/Bensas/miniforge3/envs/mlp/lib/python3.8/site-packages/transformers/models/auto/tokenization_auto.py?line=335'>336</a>         force_download=force_download,
#     <a href='file:///Users/Bensas/miniforge3/envs/mlp/lib/python3.8/site-packages/transformers/models/auto/tokenization_auto.py?line=336'>337</a>         resume_download=resume_download,
#     <a href='file:///Users/Bensas/miniforge3/envs/mlp/lib/python3.8/site-packages/transformers/models/auto/tokenization_auto.py?line=337'>338</a>         proxies=proxies,
#     <a href='file:///Users/Bensas/miniforge3/envs/mlp/lib/python3.8/site-packages/transformers/models/auto/tokenization_auto.py?line=338'>339</a>         use_auth_token=use_auth_token,
#     <a href='file:///Users/Bensas/miniforge3/envs/mlp/lib/python3.8/site-packages/transformers/models/auto/tokenization_auto.py?line=339'>340</a>         revision=revision,
#     <a href='file:///Users/Bensas/miniforge3/envs/mlp/lib/python3.8/site-packages/transformers/models/auto/tokenization_auto.py?line=340'>341</a>         local_files_only=local_files_only,
#     <a href='file:///Users/Bensas/miniforge3/envs/mlp/lib/python3.8/site-packages/transformers/models/auto/tokenization_auto.py?line=341'>342</a>     )
#     <a href='file:///Users/Bensas/miniforge3/envs/mlp/lib/python3.8/site-packages/transformers/models/auto/tokenization_auto.py?line=342'>343</a>     if resolved_config_file is None:
#     <a href='file:///Users/Bensas/miniforge3/envs/mlp/lib/python3.8/site-packages/transformers/models/auto/tokenization_auto.py?line=343'>344</a>         logger.info("Could not locate the tokenizer configuration file, will try to use the model config instead.")
#
# File ~/miniforge3/envs/mlp/lib/python3.8/site-packages/transformers/utils/hub.py:678, in get_file_from_repo(path_or_repo, filename, cache_dir, force_download, resume_download, proxies, use_auth_token, revision, local_files_only)
#     <a href='file:///Users/Bensas/miniforge3/envs/mlp/lib/python3.8/site-packages/transformers/utils/hub.py?line=673'>674</a>     resolved_file = hf_bucket_url(path_or_repo, filename=filename, revision=revision, mirror=None)
#     <a href='file:///Users/Bensas/miniforge3/envs/mlp/lib/python3.8/site-packages/transformers/utils/hub.py?line=675'>676</a> try:
#     <a href='file:///Users/Bensas/miniforge3/envs/mlp/lib/python3.8/site-packages/transformers/utils/hub.py?line=676'>677</a>     # Load from URL or cache if already cached
# --> <a href='file:///Users/Bensas/miniforge3/envs/mlp/lib/python3.8/site-packages/transformers/utils/hub.py?line=677'>678</a>     resolved_file = cached_path(
#     <a href='file:///Users/Bensas/miniforge3/envs/mlp/lib/python3.8/site-packages/transformers/utils/hub.py?line=678'>679</a>         resolved_file,
#     <a href='file:///Users/Bensas/miniforge3/envs/mlp/lib/python3.8/site-packages/transformers/utils/hub.py?line=679'>680</a>         cache_dir=cache_dir,
#     <a href='file:///Users/Bensas/miniforge3/envs/mlp/lib/python3.8/site-packages/transformers/utils/hub.py?line=680'>681</a>         force_download=force_download,
#     <a href='file:///Users/Bensas/miniforge3/envs/mlp/lib/python3.8/site-packages/transformers/utils/hub.py?line=681'>682</a>         proxies=proxies,
#     <a href='file:///Users/Bensas/miniforge3/envs/mlp/lib/python3.8/site-packages/transformers/utils/hub.py?line=682'>683</a>         resume_download=resume_download,
#     <a href='file:///Users/Bensas/miniforge3/envs/mlp/lib/python3.8/site-packages/transformers/utils/hub.py?line=683'>684</a>         local_files_only=local_files_only,
#     <a href='file:///Users/Bensas/miniforge3/envs/mlp/lib/python3.8/site-packages/transformers/utils/hub.py?line=684'>685</a>         use_auth_token=use_auth_token,
#     <a href='file:///Users/Bensas/miniforge3/envs/mlp/lib/python3.8/site-packages/transformers/utils/hub.py?line=685'>686</a>     )
#     <a href='file:///Users/Bensas/miniforge3/envs/mlp/lib/python3.8/site-packages/transformers/utils/hub.py?line=687'>688</a> except RepositoryNotFoundError:
#     <a href='file:///Users/Bensas/miniforge3/envs/mlp/lib/python3.8/site-packages/transformers/utils/hub.py?line=688'>689</a>     raise EnvironmentError(
#     <a href='file:///Users/Bensas/miniforge3/envs/mlp/lib/python3.8/site-packages/transformers/utils/hub.py?line=689'>690</a>         f"{path_or_repo} is not a local folder and is not a valid model identifier "
#     <a href='file:///Users/Bensas/miniforge3/envs/mlp/lib/python3.8/site-packages/transformers/utils/hub.py?line=690'>691</a>         "listed on 'https://huggingface.co/models'\nIf this is a private repository, make sure to "
#     <a href='file:///Users/Bensas/miniforge3/envs/mlp/lib/python3.8/site-packages/transformers/utils/hub.py?line=691'>692</a>         "pass a token having permission to this repo with `use_auth_token` or log in with "
#     <a href='file:///Users/Bensas/miniforge3/envs/mlp/lib/python3.8/site-packages/transformers/utils/hub.py?line=692'>693</a>         "`huggingface-cli login` and pass `use_auth_token=True`."
#     <a href='file:///Users/Bensas/miniforge3/envs/mlp/lib/python3.8/site-packages/transformers/utils/hub.py?line=693'>694</a>     )
#
# File ~/miniforge3/envs/mlp/lib/python3.8/site-packages/transformers/utils/hub.py:282, in cached_path(url_or_filename, cache_dir, force_download, proxies, resume_download, user_agent, extract_compressed_file, force_extract, use_auth_token, local_files_only)
#     <a href='file:///Users/Bensas/miniforge3/envs/mlp/lib/python3.8/site-packages/transformers/utils/hub.py?line=277'>278</a>     local_files_only = True
#     <a href='file:///Users/Bensas/miniforge3/envs/mlp/lib/python3.8/site-packages/transformers/utils/hub.py?line=279'>280</a> if is_remote_url(url_or_filename):
#     <a href='file:///Users/Bensas/miniforge3/envs/mlp/lib/python3.8/site-packages/transformers/utils/hub.py?line=280'>281</a>     # URL, so get it from the cache (downloading if necessary)
# --> <a href='file:///Users/Bensas/miniforge3/envs/mlp/lib/python3.8/site-packages/transformers/utils/hub.py?line=281'>282</a>     output_path = get_from_cache(
#     <a href='file:///Users/Bensas/miniforge3/envs/mlp/lib/python3.8/site-packages/transformers/utils/hub.py?line=282'>283</a>         url_or_filename,
#     <a href='file:///Users/Bensas/miniforge3/envs/mlp/lib/python3.8/site-packages/transformers/utils/hub.py?line=283'>284</a>         cache_dir=cache_dir,
#     <a href='file:///Users/Bensas/miniforge3/envs/mlp/lib/python3.8/site-packages/transformers/utils/hub.py?line=284'>285</a>         force_download=force_download,
#     <a href='file:///Users/Bensas/miniforge3/envs/mlp/lib/python3.8/site-packages/transformers/utils/hub.py?line=285'>286</a>         proxies=proxies,
#     <a href='file:///Users/Bensas/miniforge3/envs/mlp/lib/python3.8/site-packages/transformers/utils/hub.py?line=286'>287</a>         resume_download=resume_download,
#     <a href='file:///Users/Bensas/miniforge3/envs/mlp/lib/python3.8/site-packages/transformers/utils/hub.py?line=287'>288</a>         user_agent=user_agent,
#     <a href='file:///Users/Bensas/miniforge3/envs/mlp/lib/python3.8/site-packages/transformers/utils/hub.py?line=288'>289</a>         use_auth_token=use_auth_token,
#     <a href='file:///Users/Bensas/miniforge3/envs/mlp/lib/python3.8/site-packages/transformers/utils/hub.py?line=289'>290</a>         local_files_only=local_files_only,
#     <a href='file:///Users/Bensas/miniforge3/envs/mlp/lib/python3.8/site-packages/transformers/utils/hub.py?line=290'>291</a>     )
#     <a href='file:///Users/Bensas/miniforge3/envs/mlp/lib/python3.8/site-packages/transformers/utils/hub.py?line=291'>292</a> elif os.path.exists(url_or_filename):
#     <a href='file:///Users/Bensas/miniforge3/envs/mlp/lib/python3.8/site-packages/transformers/utils/hub.py?line=292'>293</a>     # File, and it exists.
#     <a href='file:///Users/Bensas/miniforge3/envs/mlp/lib/python3.8/site-packages/transformers/utils/hub.py?line=293'>294</a>     output_path = url_or_filename
#
# File ~/miniforge3/envs/mlp/lib/python3.8/site-packages/transformers/utils/hub.py:545, in get_from_cache(url, cache_dir, force_download, proxies, etag_timeout, resume_download, user_agent, use_auth_token, local_files_only)
#     <a href='file:///Users/Bensas/miniforge3/envs/mlp/lib/python3.8/site-packages/transformers/utils/hub.py?line=538'>539</a>                 raise FileNotFoundError(
#     <a href='file:///Users/Bensas/miniforge3/envs/mlp/lib/python3.8/site-packages/transformers/utils/hub.py?line=539'>540</a>                     "Cannot find the requested files in the cached path and outgoing traffic has been"
#     <a href='file:///Users/Bensas/miniforge3/envs/mlp/lib/python3.8/site-packages/transformers/utils/hub.py?line=540'>541</a>                     " disabled. To enable model look-ups and downloads online, set 'local_files_only'"
#     <a href='file:///Users/Bensas/miniforge3/envs/mlp/lib/python3.8/site-packages/transformers/utils/hub.py?line=541'>542</a>                     " to False."
#     <a href='file:///Users/Bensas/miniforge3/envs/mlp/lib/python3.8/site-packages/transformers/utils/hub.py?line=542'>543</a>                 )
#     <a href='file:///Users/Bensas/miniforge3/envs/mlp/lib/python3.8/site-packages/transformers/utils/hub.py?line=543'>544</a>             else:
# --> <a href='file:///Users/Bensas/miniforge3/envs/mlp/lib/python3.8/site-packages/transformers/utils/hub.py?line=544'>545</a>                 raise ValueError(
#     <a href='file:///Users/Bensas/miniforge3/envs/mlp/lib/python3.8/site-packages/transformers/utils/hub.py?line=545'>546</a>                     "Connection error, and we cannot find the requested files in the cached path."
#     <a href='file:///Users/Bensas/miniforge3/envs/mlp/lib/python3.8/site-packages/transformers/utils/hub.py?line=546'>547</a>                     " Please try again or make sure your Internet connection is on."
#     <a href='file:///Users/Bensas/miniforge3/envs/mlp/lib/python3.8/site-packages/transformers/utils/hub.py?line=547'>548</a>                 )
#     <a href='file:///Users/Bensas/miniforge3/envs/mlp/lib/python3.8/site-packages/transformers/utils/hub.py?line=549'>550</a> # From now on, etag is not None.
#     <a href='file:///Users/Bensas/miniforge3/envs/mlp/lib/python3.8/site-packages/transformers/utils/hub.py?line=550'>551</a> if os.path.exists(cache_path) and not force_download:
#
# ValueError: Connection error, and we cannot find the requested files in the cached path. Please try again or make sure your Internet connection is on.

# %%
q2_path_2 = '../DataCollection/scrapping/output/q2/putin_english.csv'
run_sentiment_analysis_and_save(q2_path_2)
# Out:
# Loaded tweets at data/q2/putin_english.csv
# Some weights of the model checkpoint at cardiffnlp/twitter-roberta-base-sentiment-latest were not used when initializing RobertaForSequenceClassification: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Running Sentiment Analysis...
# Time elapsed:  1128.437345981598  seconds

# %%
q2_path_3 = '../DataCollection/scrapping/output/q2/zelensky_english.csv'
run_sentiment_analysis_and_save(q2_path_3)
# Out:
# 27507 27505
# Loaded tweets at data/q2/zelensky_english.csv
# Some weights of the model checkpoint at cardiffnlp/twitter-roberta-base-sentiment-latest were not used when initializing RobertaForSequenceClassification: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Running Sentiment Analysis...
# Time elapsed:  1356.382895231247  seconds

# %% [markdown]
# ### Russian

# %%
model_path = f"cointegrated/rubert-tiny-sentiment-balanced"
q2_path_4 = 'data/q2/nato_russian.csv'
run_sentiment_analysis_and_save(q2_path_4, model_path)
# Out:
# Removed  0 invalid tweets
# Loaded tweets at data/q2/nato_russian.csv
# Running Sentiment Analysis...
# Time elapsed:  0.08802032470703125  seconds

# %%
q2_path_5 = 'data/q2/putin_russian.csv'
run_sentiment_analysis_and_save(q2_path_5, model_path)
# Out:
# Removed  0 invalid tweets
# Loaded tweets at data/q2/putin_russian.csv
# Running Sentiment Analysis...
# Time elapsed:  232.93544363975525  seconds

# %%
q2_path_6 = 'data/q2/zelensky_russian.csv'
run_sentiment_analysis_and_save(q2_path_6, model_path)
# Out:
# Removed  0 invalid tweets
# Loaded tweets at data/q2/zelensky_russian.csv
# Running Sentiment Analysis...
# Time elapsed:  232.61395645141602  seconds

# %% [markdown]
# ## Q3

# %% [markdown]
# I am making some significant changes here.
# First I am using the data that I scrapped, which only contains the news titles and nothing else (replies and retweets).
# They contain all tweets posted from the channels from Dec to April, so I have to manually later sort out Ukranian war related tweets

# %%
q3_path_1 = '../DataCollection/scrapping/output/q3/FoxNews_Sheikh.csv'
run_sentiment_analysis_and_save(q3_path_1)
# Out:
# Removed  0 invalid tweets
# Loaded tweets at data/q3/FoxNews_Sheikh.csv
# Some weights of the model checkpoint at cardiffnlp/twitter-roberta-base-sentiment-latest were not used when initializing RobertaForSequenceClassification: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Running Sentiment Analysis...
# Time elapsed:  728.9498617649078  seconds
#                             Date  \
# 0      2022-04-29 23:50:08+00:00
# 1      2022-04-29 23:40:07+00:00
# 2      2022-04-29 23:30:00+00:00
# 3      2022-04-29 23:20:00+00:00
# 4      2022-04-29 23:10:00+00:00
# ...                          ...
# 22500  2021-12-01 00:57:39+00:00
# 22501  2021-12-01 00:47:31+00:00
# 22502  2021-12-01 00:35:05+00:00
# 22503  2021-12-01 00:20:03+00:00
# 22504  2021-12-01 00:02:45+00:00
#
#                                                     text
# 0      OPINION: @user @user Biden thinks student loan...
# 1      Clinton campaign seeks to block Durham access ...
# 2      NYC bystander stabbed by group outside club in...
# 3      Met Gala 2022 'Gilded Glamour' theme gets mixe...
# 4      Elon Musk and Amber Heard: What we learned thi...
# ...                                                  ...
# 22500  Gutfeld: 'It's going to be a war' between arme...
# 22501  Illegal immigrant posed as rideshare driver an...
# 22502  Salvation Army pulls controversial racism guid...
# 22503  'Sex and the City' spin-off releases full trai...
# 22504  'Rust' shooting: Police release fourth search ...
#
# [22505 rows x 2 columns]

# %%
q3_path_2 = 'data/q3/NYT_Sheikh.csv'
run_sentiment_analysis_and_save(q3_path_2)
# Out:
# Removed  0 invalid tweets
# Loaded tweets at data/q3/NYT_Sheikh.csv
# Some weights of the model checkpoint at cardiffnlp/twitter-roberta-base-sentiment-latest were not used when initializing RobertaForSequenceClassification: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Running Sentiment Analysis...
# Time elapsed:  1622.3399460315704  seconds
#                             Date  \
# 0      2022-04-29 23:40:08+00:00
# 1      2022-04-29 23:00:10+00:00
# 2      2022-04-29 22:40:05+00:00
# 3      2022-04-29 22:00:16+00:00
# 4      2022-04-29 21:53:06+00:00
# ...                          ...
# 12388  2021-12-01 00:50:07+00:00
# 12389  2021-12-01 00:40:03+00:00
# 12390  2021-12-01 00:30:09+00:00
# 12391  2021-12-01 00:15:08+00:00
# 12392  2021-12-01 00:00:09+00:00
#
#                                                     text
# 0      Linemen and receivers took center stage in the...
# 1      In Opinion\n\nJ.D. Vance's "Trumpian turn has ...
# 2      The pandemic has upended the rigid 9-to-5 work...
# 3      As a Manhattan grand jury wraps up its review ...
# 4      “If Mariupol is hell, Azovstal is worse.” The ...
# ...                                                  ...
# 12388  After thirteen cases of the Omicron variant we...
# 12389  "The last time I was inside the walls of Oxfor...
# 12390  Detectives investigating the deadly shooting o...
# 12391  Josh Duggar, who gained celebrity on the TLC r...
# 12392  There have been 28 school shootings in the U.S...
#
# [12393 rows x 2 columns]
