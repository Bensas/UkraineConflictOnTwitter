# %%
# !jupyter nbextension enable --py widgetsnbextension
# Out:
# Enabling notebook extension jupyter-js-widgets/extension...
#       - Validating: OK

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
import torch
from transformers import pipeline
from transformers.pipelines.pt_utils import Dataset, KeyDataset
import time
from tqdm.auto import tqdm

# %%
class ListDataset(Dataset):
    def __init__(self, original_list):
        self.original_list = original_list

    def __len__(self):
        return len(self.original_list)
    
    def __getitem__(self, i):
        return self.original_list[i]

# %%
#I modified this code quite a bit, now it only returns date and tweet text (preprocessed). username and language are excluded
def run_sentiment_analysis_and_save(path_to_tweets, model_path = f"cardiffnlp/twitter-roberta-base-sentiment-latest"):
    input_csv = pd.read_csv(path_to_tweets) 
    input_csv.head()
    tweet_text = input_csv['Tweet'].to_list()
    #this dataframe column should be changed for question 1 and 2 to "tweetcreatedts" and for question 3 "Date"
    tweet_date = input_csv['Date'].to_list()  
    filtered_tweets = [text for text in tweet_text if type(text) == str] # If some tweets have no text for whatever reason, we remove them
    print('Removed ', len(tweet_text) - len(filtered_tweets), 'invalid tweets')
    

    #Adding a preprocessing step to remove links and users
    pre_processed = [] #we put all the filtered tweets in this array
    for tweet in filtered_tweets:
        tweet_words = [] 
        for word in tweet.split(' '):
            if word.startswith('@') and len(word) > 1: #if it is a mention then it starts with @ 
                word = '@user'
            elif "http" in word:
                i = word.index("http")
                word = word[:i] + "http"
            #    word = "http"
            tweet_words.append(word)
        tweet = " ".join(tweet_words)
        pre_processed.append(tweet)

    


    # print(tweet_text[:10])
    # tweets_dataset = ListDataset(tweet_text)
    print('Loaded tweets at ' + path_to_tweets)

    sentiment_pipeline = pipeline("sentiment-analysis", model=model_path, tokenizer=model_path, max_length=512, truncation=True)
    
    print('Running Sentiment Analysis...')
    start_time = time.time()
    result = sentiment_pipeline(pre_processed)
    end_time = time.time()
    print('Time elapsed: ', end_time - start_time, ' seconds')

    #added by Sheikh, feel free to fix if you find any issue
    data_given = {"Date": tweet_date, "text": pre_processed}
    data_given = pd.DataFrame(data_given)
    result = pd.DataFrame(result)
    result_df = data_given.join(result)
    result_df.to_csv(path_to_tweets.split('.csv')[0] + '_with_sentiment.csv')
    #data_given.to_csv(path_to_tweets.split('.csv')[0] + 'test_preprocessing.csv')
    return data_given

# %% [markdown]
# ## Q1

# %%
q1_path = 'data/q1/all_tweets.csv'
run_sentiment_analysis_and_save(q1_path)
# Out:
# Removed  0 invalid tweets
# Loaded tweets at data/q1/all_tweets.csv
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Volumes/GoogleDrive/My Drive/Spring 2022/Data Science Methodology/UkraineConflictOnTwitter/SentimentAnalysis/TwitterSentimentAnalysis.ipynb Cell 8' in <cell line: 2>()
#       <a href='vscode-notebook-cell:/Volumes/GoogleDrive/My%20Drive/Spring%202022/Data%20Science%20Methodology/UkraineConflictOnTwitter/SentimentAnalysis/TwitterSentimentAnalysis.ipynb#ch0000007?line=0'>1</a> q1_path = 'data/q1/all_tweets.csv'
# ----> <a href='vscode-notebook-cell:/Volumes/GoogleDrive/My%20Drive/Spring%202022/Data%20Science%20Methodology/UkraineConflictOnTwitter/SentimentAnalysis/TwitterSentimentAnalysis.ipynb#ch0000007?line=1'>2</a> run_sentiment_analysis_and_save(q1_path)
#
# /Volumes/GoogleDrive/My Drive/Spring 2022/Data Science Methodology/UkraineConflictOnTwitter/SentimentAnalysis/TwitterSentimentAnalysis.ipynb Cell 6' in run_sentiment_analysis_and_save(path_to_tweets, model_path)
#      <a href='vscode-notebook-cell:/Volumes/GoogleDrive/My%20Drive/Spring%202022/Data%20Science%20Methodology/UkraineConflictOnTwitter/SentimentAnalysis/TwitterSentimentAnalysis.ipynb#ch0000005?line=29'>30</a> # print(tweet_text[:10])
#      <a href='vscode-notebook-cell:/Volumes/GoogleDrive/My%20Drive/Spring%202022/Data%20Science%20Methodology/UkraineConflictOnTwitter/SentimentAnalysis/TwitterSentimentAnalysis.ipynb#ch0000005?line=30'>31</a> # tweets_dataset = ListDataset(tweet_text)
#      <a href='vscode-notebook-cell:/Volumes/GoogleDrive/My%20Drive/Spring%202022/Data%20Science%20Methodology/UkraineConflictOnTwitter/SentimentAnalysis/TwitterSentimentAnalysis.ipynb#ch0000005?line=31'>32</a> print('Loaded tweets at ' + path_to_tweets)
# ---> <a href='vscode-notebook-cell:/Volumes/GoogleDrive/My%20Drive/Spring%202022/Data%20Science%20Methodology/UkraineConflictOnTwitter/SentimentAnalysis/TwitterSentimentAnalysis.ipynb#ch0000005?line=33'>34</a> sentiment_pipeline = pipeline("sentiment-analysis", model=model_path, tokenizer=model_path, max_length=512, truncation=True)
#      <a href='vscode-notebook-cell:/Volumes/GoogleDrive/My%20Drive/Spring%202022/Data%20Science%20Methodology/UkraineConflictOnTwitter/SentimentAnalysis/TwitterSentimentAnalysis.ipynb#ch0000005?line=35'>36</a> print('Running Sentiment Analysis...')
#      <a href='vscode-notebook-cell:/Volumes/GoogleDrive/My%20Drive/Spring%202022/Data%20Science%20Methodology/UkraineConflictOnTwitter/SentimentAnalysis/TwitterSentimentAnalysis.ipynb#ch0000005?line=36'>37</a> start_time = time.time()
#
# File ~/miniforge3/envs/tsttf/lib/python3.8/site-packages/transformers/pipelines/__init__.py:549, in pipeline(task, model, config, tokenizer, feature_extractor, framework, revision, use_fast, use_auth_token, model_kwargs, pipeline_class, **kwargs)
#     <a href='file:///Users/sheikh/miniforge3/envs/tsttf/lib/python3.8/site-packages/transformers/pipelines/__init__.py?line=544'>545</a> # Infer the framework from the model
#     <a href='file:///Users/sheikh/miniforge3/envs/tsttf/lib/python3.8/site-packages/transformers/pipelines/__init__.py?line=545'>546</a> # Forced if framework already defined, inferred if it's None
#     <a href='file:///Users/sheikh/miniforge3/envs/tsttf/lib/python3.8/site-packages/transformers/pipelines/__init__.py?line=546'>547</a> # Will load the correct model if possible
#     <a href='file:///Users/sheikh/miniforge3/envs/tsttf/lib/python3.8/site-packages/transformers/pipelines/__init__.py?line=547'>548</a> model_classes = {"tf": targeted_task["tf"], "pt": targeted_task["pt"]}
# --> <a href='file:///Users/sheikh/miniforge3/envs/tsttf/lib/python3.8/site-packages/transformers/pipelines/__init__.py?line=548'>549</a> framework, model = infer_framework_load_model(
#     <a href='file:///Users/sheikh/miniforge3/envs/tsttf/lib/python3.8/site-packages/transformers/pipelines/__init__.py?line=549'>550</a>     model,
#     <a href='file:///Users/sheikh/miniforge3/envs/tsttf/lib/python3.8/site-packages/transformers/pipelines/__init__.py?line=550'>551</a>     model_classes=model_classes,
#     <a href='file:///Users/sheikh/miniforge3/envs/tsttf/lib/python3.8/site-packages/transformers/pipelines/__init__.py?line=551'>552</a>     config=config,
#     <a href='file:///Users/sheikh/miniforge3/envs/tsttf/lib/python3.8/site-packages/transformers/pipelines/__init__.py?line=552'>553</a>     framework=framework,
#     <a href='file:///Users/sheikh/miniforge3/envs/tsttf/lib/python3.8/site-packages/transformers/pipelines/__init__.py?line=553'>554</a>     revision=revision,
#     <a href='file:///Users/sheikh/miniforge3/envs/tsttf/lib/python3.8/site-packages/transformers/pipelines/__init__.py?line=554'>555</a>     task=task,
#     <a href='file:///Users/sheikh/miniforge3/envs/tsttf/lib/python3.8/site-packages/transformers/pipelines/__init__.py?line=555'>556</a>     **model_kwargs,
#     <a href='file:///Users/sheikh/miniforge3/envs/tsttf/lib/python3.8/site-packages/transformers/pipelines/__init__.py?line=556'>557</a> )
#     <a href='file:///Users/sheikh/miniforge3/envs/tsttf/lib/python3.8/site-packages/transformers/pipelines/__init__.py?line=558'>559</a> model_config = model.config
#     <a href='file:///Users/sheikh/miniforge3/envs/tsttf/lib/python3.8/site-packages/transformers/pipelines/__init__.py?line=560'>561</a> load_tokenizer = type(model_config) in TOKENIZER_MAPPING or model_config.tokenizer_class is not None
#
# File ~/miniforge3/envs/tsttf/lib/python3.8/site-packages/transformers/pipelines/base.py:246, in infer_framework_load_model(model, config, model_classes, task, framework, **model_kwargs)
#     <a href='file:///Users/sheikh/miniforge3/envs/tsttf/lib/python3.8/site-packages/transformers/pipelines/base.py?line=239'>240</a>     logger.warning(
#     <a href='file:///Users/sheikh/miniforge3/envs/tsttf/lib/python3.8/site-packages/transformers/pipelines/base.py?line=240'>241</a>         "Model might be a PyTorch model (ending with `.bin`) but PyTorch is not available. "
#     <a href='file:///Users/sheikh/miniforge3/envs/tsttf/lib/python3.8/site-packages/transformers/pipelines/base.py?line=241'>242</a>         "Trying to load the model with Tensorflow."
#     <a href='file:///Users/sheikh/miniforge3/envs/tsttf/lib/python3.8/site-packages/transformers/pipelines/base.py?line=242'>243</a>     )
#     <a href='file:///Users/sheikh/miniforge3/envs/tsttf/lib/python3.8/site-packages/transformers/pipelines/base.py?line=244'>245</a> try:
# --> <a href='file:///Users/sheikh/miniforge3/envs/tsttf/lib/python3.8/site-packages/transformers/pipelines/base.py?line=245'>246</a>     model = model_class.from_pretrained(model, **kwargs)
#     <a href='file:///Users/sheikh/miniforge3/envs/tsttf/lib/python3.8/site-packages/transformers/pipelines/base.py?line=246'>247</a>     if hasattr(model, "eval"):
#     <a href='file:///Users/sheikh/miniforge3/envs/tsttf/lib/python3.8/site-packages/transformers/pipelines/base.py?line=247'>248</a>         model = model.eval()
#
# File ~/miniforge3/envs/tsttf/lib/python3.8/site-packages/transformers/models/auto/auto_factory.py:446, in _BaseAutoModelClass.from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     <a href='file:///Users/sheikh/miniforge3/envs/tsttf/lib/python3.8/site-packages/transformers/models/auto/auto_factory.py?line=443'>444</a> elif type(config) in cls._model_mapping.keys():
#     <a href='file:///Users/sheikh/miniforge3/envs/tsttf/lib/python3.8/site-packages/transformers/models/auto/auto_factory.py?line=444'>445</a>     model_class = _get_model_class(config, cls._model_mapping)
# --> <a href='file:///Users/sheikh/miniforge3/envs/tsttf/lib/python3.8/site-packages/transformers/models/auto/auto_factory.py?line=445'>446</a>     return model_class.from_pretrained(pretrained_model_name_or_path, *model_args, config=config, **kwargs)
#     <a href='file:///Users/sheikh/miniforge3/envs/tsttf/lib/python3.8/site-packages/transformers/models/auto/auto_factory.py?line=446'>447</a> raise ValueError(
#     <a href='file:///Users/sheikh/miniforge3/envs/tsttf/lib/python3.8/site-packages/transformers/models/auto/auto_factory.py?line=447'>448</a>     f"Unrecognized configuration class {config.__class__} for this kind of AutoModel: {cls.__name__}.\n"
#     <a href='file:///Users/sheikh/miniforge3/envs/tsttf/lib/python3.8/site-packages/transformers/models/auto/auto_factory.py?line=448'>449</a>     f"Model type should be one of {', '.join(c.__name__ for c in cls._model_mapping.keys())}."
#     <a href='file:///Users/sheikh/miniforge3/envs/tsttf/lib/python3.8/site-packages/transformers/models/auto/auto_factory.py?line=449'>450</a> )
#
# File ~/miniforge3/envs/tsttf/lib/python3.8/site-packages/transformers/modeling_utils.py:2024, in PreTrainedModel.from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#    <a href='file:///Users/sheikh/miniforge3/envs/tsttf/lib/python3.8/site-packages/transformers/modeling_utils.py?line=2021'>2022</a> else:
#    <a href='file:///Users/sheikh/miniforge3/envs/tsttf/lib/python3.8/site-packages/transformers/modeling_utils.py?line=2022'>2023</a>     with no_init_weights(_enable=_fast_init):
# -> <a href='file:///Users/sheikh/miniforge3/envs/tsttf/lib/python3.8/site-packages/transformers/modeling_utils.py?line=2023'>2024</a>         model = cls(config, *model_args, **model_kwargs)
#    <a href='file:///Users/sheikh/miniforge3/envs/tsttf/lib/python3.8/site-packages/transformers/modeling_utils.py?line=2025'>2026</a> if from_tf:
#    <a href='file:///Users/sheikh/miniforge3/envs/tsttf/lib/python3.8/site-packages/transformers/modeling_utils.py?line=2026'>2027</a>     if resolved_archive_file.endswith(".index"):
#    <a href='file:///Users/sheikh/miniforge3/envs/tsttf/lib/python3.8/site-packages/transformers/modeling_utils.py?line=2027'>2028</a>         # Load from a TensorFlow 1.X checkpoint - provided by original authors
#
# File ~/miniforge3/envs/tsttf/lib/python3.8/site-packages/transformers/models/roberta/modeling_roberta.py:1169, in RobertaForSequenceClassification.__init__(self, config)
#    <a href='file:///Users/sheikh/miniforge3/envs/tsttf/lib/python3.8/site-packages/transformers/models/roberta/modeling_roberta.py?line=1165'>1166</a> self.num_labels = config.num_labels
#    <a href='file:///Users/sheikh/miniforge3/envs/tsttf/lib/python3.8/site-packages/transformers/models/roberta/modeling_roberta.py?line=1166'>1167</a> self.config = config
# -> <a href='file:///Users/sheikh/miniforge3/envs/tsttf/lib/python3.8/site-packages/transformers/models/roberta/modeling_roberta.py?line=1168'>1169</a> self.roberta = RobertaModel(config, add_pooling_layer=False)
#    <a href='file:///Users/sheikh/miniforge3/envs/tsttf/lib/python3.8/site-packages/transformers/models/roberta/modeling_roberta.py?line=1169'>1170</a> self.classifier = RobertaClassificationHead(config)
#    <a href='file:///Users/sheikh/miniforge3/envs/tsttf/lib/python3.8/site-packages/transformers/models/roberta/modeling_roberta.py?line=1171'>1172</a> # Initialize weights and apply final processing
#
# File ~/miniforge3/envs/tsttf/lib/python3.8/site-packages/transformers/models/roberta/modeling_roberta.py:716, in RobertaModel.__init__(self, config, add_pooling_layer)
#     <a href='file:///Users/sheikh/miniforge3/envs/tsttf/lib/python3.8/site-packages/transformers/models/roberta/modeling_roberta.py?line=712'>713</a> self.config = config
#     <a href='file:///Users/sheikh/miniforge3/envs/tsttf/lib/python3.8/site-packages/transformers/models/roberta/modeling_roberta.py?line=714'>715</a> self.embeddings = RobertaEmbeddings(config)
# --> <a href='file:///Users/sheikh/miniforge3/envs/tsttf/lib/python3.8/site-packages/transformers/models/roberta/modeling_roberta.py?line=715'>716</a> self.encoder = RobertaEncoder(config)
#     <a href='file:///Users/sheikh/miniforge3/envs/tsttf/lib/python3.8/site-packages/transformers/models/roberta/modeling_roberta.py?line=717'>718</a> self.pooler = RobertaPooler(config) if add_pooling_layer else None
#     <a href='file:///Users/sheikh/miniforge3/envs/tsttf/lib/python3.8/site-packages/transformers/models/roberta/modeling_roberta.py?line=719'>720</a> # Initialize weights and apply final processing
#
# File ~/miniforge3/envs/tsttf/lib/python3.8/site-packages/transformers/models/roberta/modeling_roberta.py:472, in RobertaEncoder.__init__(self, config)
#     <a href='file:///Users/sheikh/miniforge3/envs/tsttf/lib/python3.8/site-packages/transformers/models/roberta/modeling_roberta.py?line=469'>470</a> super().__init__()
#     <a href='file:///Users/sheikh/miniforge3/envs/tsttf/lib/python3.8/site-packages/transformers/models/roberta/modeling_roberta.py?line=470'>471</a> self.config = config
# --> <a href='file:///Users/sheikh/miniforge3/envs/tsttf/lib/python3.8/site-packages/transformers/models/roberta/modeling_roberta.py?line=471'>472</a> self.layer = nn.ModuleList([RobertaLayer(config) for _ in range(config.num_hidden_layers)])
#     <a href='file:///Users/sheikh/miniforge3/envs/tsttf/lib/python3.8/site-packages/transformers/models/roberta/modeling_roberta.py?line=472'>473</a> self.gradient_checkpointing = False
#
# File ~/miniforge3/envs/tsttf/lib/python3.8/site-packages/transformers/models/roberta/modeling_roberta.py:472, in <listcomp>(.0)
#     <a href='file:///Users/sheikh/miniforge3/envs/tsttf/lib/python3.8/site-packages/transformers/models/roberta/modeling_roberta.py?line=469'>470</a> super().__init__()
#     <a href='file:///Users/sheikh/miniforge3/envs/tsttf/lib/python3.8/site-packages/transformers/models/roberta/modeling_roberta.py?line=470'>471</a> self.config = config
# --> <a href='file:///Users/sheikh/miniforge3/envs/tsttf/lib/python3.8/site-packages/transformers/models/roberta/modeling_roberta.py?line=471'>472</a> self.layer = nn.ModuleList([RobertaLayer(config) for _ in range(config.num_hidden_layers)])
#     <a href='file:///Users/sheikh/miniforge3/envs/tsttf/lib/python3.8/site-packages/transformers/models/roberta/modeling_roberta.py?line=472'>473</a> self.gradient_checkpointing = False
#
# File ~/miniforge3/envs/tsttf/lib/python3.8/site-packages/transformers/models/roberta/modeling_roberta.py:387, in RobertaLayer.__init__(self, config)
#     <a href='file:///Users/sheikh/miniforge3/envs/tsttf/lib/python3.8/site-packages/transformers/models/roberta/modeling_roberta.py?line=384'>385</a> self.chunk_size_feed_forward = config.chunk_size_feed_forward
#     <a href='file:///Users/sheikh/miniforge3/envs/tsttf/lib/python3.8/site-packages/transformers/models/roberta/modeling_roberta.py?line=385'>386</a> self.seq_len_dim = 1
# --> <a href='file:///Users/sheikh/miniforge3/envs/tsttf/lib/python3.8/site-packages/transformers/models/roberta/modeling_roberta.py?line=386'>387</a> self.attention = RobertaAttention(config)
#     <a href='file:///Users/sheikh/miniforge3/envs/tsttf/lib/python3.8/site-packages/transformers/models/roberta/modeling_roberta.py?line=387'>388</a> self.is_decoder = config.is_decoder
#     <a href='file:///Users/sheikh/miniforge3/envs/tsttf/lib/python3.8/site-packages/transformers/models/roberta/modeling_roberta.py?line=388'>389</a> self.add_cross_attention = config.add_cross_attention
#
# File ~/miniforge3/envs/tsttf/lib/python3.8/site-packages/transformers/models/roberta/modeling_roberta.py:304, in RobertaAttention.__init__(self, config, position_embedding_type)
#     <a href='file:///Users/sheikh/miniforge3/envs/tsttf/lib/python3.8/site-packages/transformers/models/roberta/modeling_roberta.py?line=301'>302</a> def __init__(self, config, position_embedding_type=None):
#     <a href='file:///Users/sheikh/miniforge3/envs/tsttf/lib/python3.8/site-packages/transformers/models/roberta/modeling_roberta.py?line=302'>303</a>     super().__init__()
# --> <a href='file:///Users/sheikh/miniforge3/envs/tsttf/lib/python3.8/site-packages/transformers/models/roberta/modeling_roberta.py?line=303'>304</a>     self.self = RobertaSelfAttention(config, position_embedding_type=position_embedding_type)
#     <a href='file:///Users/sheikh/miniforge3/envs/tsttf/lib/python3.8/site-packages/transformers/models/roberta/modeling_roberta.py?line=304'>305</a>     self.output = RobertaSelfOutput(config)
#     <a href='file:///Users/sheikh/miniforge3/envs/tsttf/lib/python3.8/site-packages/transformers/models/roberta/modeling_roberta.py?line=305'>306</a>     self.pruned_heads = set()
#
# File ~/miniforge3/envs/tsttf/lib/python3.8/site-packages/transformers/models/roberta/modeling_roberta.py:172, in RobertaSelfAttention.__init__(self, config, position_embedding_type)
#     <a href='file:///Users/sheikh/miniforge3/envs/tsttf/lib/python3.8/site-packages/transformers/models/roberta/modeling_roberta.py?line=168'>169</a> self.all_head_size = self.num_attention_heads * self.attention_head_size
#     <a href='file:///Users/sheikh/miniforge3/envs/tsttf/lib/python3.8/site-packages/transformers/models/roberta/modeling_roberta.py?line=170'>171</a> self.query = nn.Linear(config.hidden_size, self.all_head_size)
# --> <a href='file:///Users/sheikh/miniforge3/envs/tsttf/lib/python3.8/site-packages/transformers/models/roberta/modeling_roberta.py?line=171'>172</a> self.key = nn.Linear(config.hidden_size, self.all_head_size)
#     <a href='file:///Users/sheikh/miniforge3/envs/tsttf/lib/python3.8/site-packages/transformers/models/roberta/modeling_roberta.py?line=172'>173</a> self.value = nn.Linear(config.hidden_size, self.all_head_size)
#     <a href='file:///Users/sheikh/miniforge3/envs/tsttf/lib/python3.8/site-packages/transformers/models/roberta/modeling_roberta.py?line=174'>175</a> self.dropout = nn.Dropout(config.attention_probs_dropout_prob)
#
# File ~/miniforge3/envs/tsttf/lib/python3.8/site-packages/torch/nn/modules/linear.py:90, in Linear.__init__(self, in_features, out_features, bias, device, dtype)
#      <a href='file:///Users/sheikh/miniforge3/envs/tsttf/lib/python3.8/site-packages/torch/nn/modules/linear.py?line=87'>88</a> else:
#      <a href='file:///Users/sheikh/miniforge3/envs/tsttf/lib/python3.8/site-packages/torch/nn/modules/linear.py?line=88'>89</a>     self.register_parameter('bias', None)
# ---> <a href='file:///Users/sheikh/miniforge3/envs/tsttf/lib/python3.8/site-packages/torch/nn/modules/linear.py?line=89'>90</a> self.reset_parameters()
#
# File ~/miniforge3/envs/tsttf/lib/python3.8/site-packages/torch/nn/modules/linear.py:96, in Linear.reset_parameters(self)
#      <a href='file:///Users/sheikh/miniforge3/envs/tsttf/lib/python3.8/site-packages/torch/nn/modules/linear.py?line=91'>92</a> def reset_parameters(self) -> None:
#      <a href='file:///Users/sheikh/miniforge3/envs/tsttf/lib/python3.8/site-packages/torch/nn/modules/linear.py?line=92'>93</a>     # Setting a=sqrt(5) in kaiming_uniform is the same as initializing with
#      <a href='file:///Users/sheikh/miniforge3/envs/tsttf/lib/python3.8/site-packages/torch/nn/modules/linear.py?line=93'>94</a>     # uniform(-1/sqrt(in_features), 1/sqrt(in_features)). For details, see
#      <a href='file:///Users/sheikh/miniforge3/envs/tsttf/lib/python3.8/site-packages/torch/nn/modules/linear.py?line=94'>95</a>     # https://github.com/pytorch/pytorch/issues/57109
# ---> <a href='file:///Users/sheikh/miniforge3/envs/tsttf/lib/python3.8/site-packages/torch/nn/modules/linear.py?line=95'>96</a>     init.kaiming_uniform_(self.weight, a=math.sqrt(5))
#      <a href='file:///Users/sheikh/miniforge3/envs/tsttf/lib/python3.8/site-packages/torch/nn/modules/linear.py?line=96'>97</a>     if self.bias is not None:
#      <a href='file:///Users/sheikh/miniforge3/envs/tsttf/lib/python3.8/site-packages/torch/nn/modules/linear.py?line=97'>98</a>         fan_in, _ = init._calculate_fan_in_and_fan_out(self.weight)
#
# File ~/miniforge3/envs/tsttf/lib/python3.8/site-packages/torch/nn/init.py:410, in kaiming_uniform_(tensor, a, mode, nonlinearity)
#     <a href='file:///Users/sheikh/miniforge3/envs/tsttf/lib/python3.8/site-packages/torch/nn/init.py?line=407'>408</a> bound = math.sqrt(3.0) * std  # Calculate uniform bounds from standard deviation
#     <a href='file:///Users/sheikh/miniforge3/envs/tsttf/lib/python3.8/site-packages/torch/nn/init.py?line=408'>409</a> with torch.no_grad():
# --> <a href='file:///Users/sheikh/miniforge3/envs/tsttf/lib/python3.8/site-packages/torch/nn/init.py?line=409'>410</a>     return tensor.uniform_(-bound, bound)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Q2

# %% [markdown]
# ### English

# %%
q2_path_1 = 'data/q2/nato_english.csv'
run_sentiment_analysis_and_save(q2_path_1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/miniforge3/envs/tsttf/lib/python3.8/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    <a href='file:///Users/sheikh/miniforge3/envs/tsttf/lib/python3.8/site-packages/pandas/core/indexes/base.py?line=3619'>3620</a> try:
# -> <a href='file:///Users/sheikh/miniforge3/envs/tsttf/lib/python3.8/site-packages/pandas/core/indexes/base.py?line=3620'>3621</a>     return self._engine.get_loc(casted_key)
#    <a href='file:///Users/sheikh/miniforge3/envs/tsttf/lib/python3.8/site-packages/pandas/core/indexes/base.py?line=3621'>3622</a> except KeyError as err:
#
# File ~/miniforge3/envs/tsttf/lib/python3.8/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/miniforge3/envs/tsttf/lib/python3.8/site-packages/pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Date'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /Volumes/GoogleDrive/My Drive/Spring 2022/Data Science Methodology/UkraineConflictOnTwitter/SentimentAnalysis/TwitterSentimentAnalysis.ipynb Cell 10' in <cell line: 2>()
#       <a href='vscode-notebook-cell:/Volumes/GoogleDrive/My%20Drive/Spring%202022/Data%20Science%20Methodology/UkraineConflictOnTwitter/SentimentAnalysis/TwitterSentimentAnalysis.ipynb#ch0000009?line=0'>1</a> q2_path_1 = 'data/q2/nato_english.csv'
# ----> <a href='vscode-notebook-cell:/Volumes/GoogleDrive/My%20Drive/Spring%202022/Data%20Science%20Methodology/UkraineConflictOnTwitter/SentimentAnalysis/TwitterSentimentAnalysis.ipynb#ch0000009?line=1'>2</a> run_sentiment_analysis_and_save(q2_path_1)
#
# /Volumes/GoogleDrive/My Drive/Spring 2022/Data Science Methodology/UkraineConflictOnTwitter/SentimentAnalysis/TwitterSentimentAnalysis.ipynb Cell 5' in run_sentiment_analysis_and_save(path_to_tweets, model_path)
#       <a href='vscode-notebook-cell:/Volumes/GoogleDrive/My%20Drive/Spring%202022/Data%20Science%20Methodology/UkraineConflictOnTwitter/SentimentAnalysis/TwitterSentimentAnalysis.ipynb#ch0000004?line=3'>4</a> input_csv.head()
#       <a href='vscode-notebook-cell:/Volumes/GoogleDrive/My%20Drive/Spring%202022/Data%20Science%20Methodology/UkraineConflictOnTwitter/SentimentAnalysis/TwitterSentimentAnalysis.ipynb#ch0000004?line=4'>5</a> tweet_text = input_csv['text'].to_list()
# ----> <a href='vscode-notebook-cell:/Volumes/GoogleDrive/My%20Drive/Spring%202022/Data%20Science%20Methodology/UkraineConflictOnTwitter/SentimentAnalysis/TwitterSentimentAnalysis.ipynb#ch0000004?line=5'>6</a> tweet_date = input_csv['Date'].to_list()
#       <a href='vscode-notebook-cell:/Volumes/GoogleDrive/My%20Drive/Spring%202022/Data%20Science%20Methodology/UkraineConflictOnTwitter/SentimentAnalysis/TwitterSentimentAnalysis.ipynb#ch0000004?line=6'>7</a> filtered_tweets = [text for text in tweet_text if type(text) == str] # If some tweets have no text for whatever reason, we remove them
#       <a href='vscode-notebook-cell:/Volumes/GoogleDrive/My%20Drive/Spring%202022/Data%20Science%20Methodology/UkraineConflictOnTwitter/SentimentAnalysis/TwitterSentimentAnalysis.ipynb#ch0000004?line=7'>8</a> print('Removed ', len(tweet_text) - len(filtered_tweets), 'invalid tweets')
#
# File ~/miniforge3/envs/tsttf/lib/python3.8/site-packages/pandas/core/frame.py:3505, in DataFrame.__getitem__(self, key)
#    <a href='file:///Users/sheikh/miniforge3/envs/tsttf/lib/python3.8/site-packages/pandas/core/frame.py?line=3502'>3503</a> if self.columns.nlevels > 1:
#    <a href='file:///Users/sheikh/miniforge3/envs/tsttf/lib/python3.8/site-packages/pandas/core/frame.py?line=3503'>3504</a>     return self._getitem_multilevel(key)
# -> <a href='file:///Users/sheikh/miniforge3/envs/tsttf/lib/python3.8/site-packages/pandas/core/frame.py?line=3504'>3505</a> indexer = self.columns.get_loc(key)
#    <a href='file:///Users/sheikh/miniforge3/envs/tsttf/lib/python3.8/site-packages/pandas/core/frame.py?line=3505'>3506</a> if is_integer(indexer):
#    <a href='file:///Users/sheikh/miniforge3/envs/tsttf/lib/python3.8/site-packages/pandas/core/frame.py?line=3506'>3507</a>     indexer = [indexer]
#
# File ~/miniforge3/envs/tsttf/lib/python3.8/site-packages/pandas/core/indexes/base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    <a href='file:///Users/sheikh/miniforge3/envs/tsttf/lib/python3.8/site-packages/pandas/core/indexes/base.py?line=3620'>3621</a>     return self._engine.get_loc(casted_key)
#    <a href='file:///Users/sheikh/miniforge3/envs/tsttf/lib/python3.8/site-packages/pandas/core/indexes/base.py?line=3621'>3622</a> except KeyError as err:
# -> <a href='file:///Users/sheikh/miniforge3/envs/tsttf/lib/python3.8/site-packages/pandas/core/indexes/base.py?line=3622'>3623</a>     raise KeyError(key) from err
#    <a href='file:///Users/sheikh/miniforge3/envs/tsttf/lib/python3.8/site-packages/pandas/core/indexes/base.py?line=3623'>3624</a> except TypeError:
#    <a href='file:///Users/sheikh/miniforge3/envs/tsttf/lib/python3.8/site-packages/pandas/core/indexes/base.py?line=3624'>3625</a>     # If we have a listlike key, _check_indexing_error will raise
#    <a href='file:///Users/sheikh/miniforge3/envs/tsttf/lib/python3.8/site-packages/pandas/core/indexes/base.py?line=3625'>3626</a>     #  InvalidIndexError. Otherwise we fall through and re-raise
#    <a href='file:///Users/sheikh/miniforge3/envs/tsttf/lib/python3.8/site-packages/pandas/core/indexes/base.py?line=3626'>3627</a>     #  the TypeError.
#    <a href='file:///Users/sheikh/miniforge3/envs/tsttf/lib/python3.8/site-packages/pandas/core/indexes/base.py?line=3627'>3628</a>     self._check_indexing_error(key)
#
# KeyError: 'Date'

# %%
q2_path_2 = 'data/q2/putin_english.csv'
run_sentiment_analysis_and_save(q2_path_2)
# Out:
# Loaded tweets at data/q2/putin_english.csv
# Some weights of the model checkpoint at cardiffnlp/twitter-roberta-base-sentiment-latest were not used when initializing RobertaForSequenceClassification: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Running Sentiment Analysis...
# Time elapsed:  1128.437345981598  seconds

# %%
q2_path_3 = 'data/q2/zelensky_english.csv'
run_sentiment_analysis_and_save(q2_path_3)
# Out:
# 27507 27505
# Loaded tweets at data/q2/zelensky_english.csv
# Some weights of the model checkpoint at cardiffnlp/twitter-roberta-base-sentiment-latest were not used when initializing RobertaForSequenceClassification: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Running Sentiment Analysis...
# Time elapsed:  1356.382895231247  seconds

# %% [markdown]
# ### Russian

# %%
model_path = f"cointegrated/rubert-tiny-sentiment-balanced"
q2_path_4 = 'data/q2/nato_russian.csv'
run_sentiment_analysis_and_save(q2_path_4, model_path)
# Out:
# Removed  0 invalid tweets
# Loaded tweets at data/q2/nato_russian.csv
# Running Sentiment Analysis...
# Time elapsed:  0.08802032470703125  seconds

# %%
q2_path_5 = 'data/q2/putin_russian.csv'
run_sentiment_analysis_and_save(q2_path_5, model_path)
# Out:
# Removed  0 invalid tweets
# Loaded tweets at data/q2/putin_russian.csv
# Running Sentiment Analysis...
# Time elapsed:  232.93544363975525  seconds

# %%
q2_path_6 = 'data/q2/zelensky_russian.csv'
run_sentiment_analysis_and_save(q2_path_6, model_path)
# Out:
# Removed  0 invalid tweets
# Loaded tweets at data/q2/zelensky_russian.csv
# Running Sentiment Analysis...
# Time elapsed:  232.61395645141602  seconds

# %% [markdown]
# ## Q3

# %% [markdown]
# I am making some significant changes here.
# Running the analysis for four sets of data I scrapped

# %%
q3_path_1 = "/Volumes/GoogleDrive/My Drive/Spring 2022/Data Science Methodology/UkraineConflictOnTwitter/DataCollection/scrapping/output/q3/May30Scrap/foxtitle.csv"
run_sentiment_analysis_and_save(q3_path_1)
# Out:
# Removed  0 invalid tweets
# Loaded tweets at /Volumes/GoogleDrive/My Drive/Spring 2022/Data Science Methodology/UkraineConflictOnTwitter/DataCollection/scrapping/output/q3/May30Scrap/foxtitle.csv
# Some weights of the model checkpoint at cardiffnlp/twitter-roberta-base-sentiment-latest were not used when initializing RobertaForSequenceClassification: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Running Sentiment Analysis...
# Time elapsed:  874.1434421539307  seconds
#                             Date  \
# 0      2022-05-23 23:50:02+00:00
# 1      2022-05-23 23:41:05+00:00
# 2      2022-05-23 23:34:41+00:00
# 3      2022-05-23 23:28:49+00:00
# 4      2022-05-23 23:25:22+00:00
# ...                          ...
# 25257  2021-12-24 01:08:42+00:00
# 25258  2021-12-24 00:55:32+00:00
# 25259  2021-12-24 00:46:17+00:00
# 25260  2021-12-24 00:26:05+00:00
# 25261  2021-12-24 00:07:05+00:00
#
#                                                     text
# 0      The Big Apple became a big headache for NY Dem...
# 1      ENEMIES ARE WATCHING: @user explains why Biden...
# 2      Hillary Clinton gave a green light to gaslight...
# 3      TONIGHT: @user weighs in on Biden’s upside dow...
# 4      ‘Jurassic Park’s’ Laura Dern, Sam Neill reflec...
# ...                                                  ...
# 25257  Karen Carpenter's brother Richard shares a fav...
# 25258  George Floyd removed from consideration for Te...
# 25259  McEnany: Biden won't be able to hide 'in the b...
# 25260  Cuomo lashes out at AG James after prosecutors...
# 25261  Biden's popularity sinking in the White House ...
#
# [25262 rows x 2 columns]

# %%
q3_path_2 = "/Volumes/GoogleDrive/My Drive/Spring 2022/Data Science Methodology/UkraineConflictOnTwitter/DataCollection/scrapping/output/q3/May30Scrap/nytitle.csv"
run_sentiment_analysis_and_save(q3_path_2)
# Out:
# Removed  0 invalid tweets
# Loaded tweets at /Volumes/GoogleDrive/My Drive/Spring 2022/Data Science Methodology/UkraineConflictOnTwitter/DataCollection/scrapping/output/q3/May30Scrap/nytitle.csv
# Some weights of the model checkpoint at cardiffnlp/twitter-roberta-base-sentiment-latest were not used when initializing RobertaForSequenceClassification: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Running Sentiment Analysis...
# Time elapsed:  537.7459280490875  seconds
#                             Date  \
# 0      2022-05-23 23:40:03+00:00
# 1      2022-05-23 23:20:03+00:00
# 2      2022-05-23 23:00:09+00:00
# 3      2022-05-23 22:40:03+00:00
# 4      2022-05-23 22:20:05+00:00
# ...                          ...
# 12259  2021-12-24 02:00:10+00:00
# 12260  2021-12-24 01:50:03+00:00
# 12261  2021-12-24 01:00:06+00:00
# 12262  2021-12-24 00:20:05+00:00
# 12263  2021-12-24 00:00:03+00:00
#
#                                                     text
# 0      As more than a dozen countries grapple with ou...
# 1      Major League Baseball suspended the Yankees th...
# 2      Former Senator David Perdue ended his campaign...
# 3      Addressing the World Economic Forum, President...
# 4      The U.S. on Monday said it would supply Romani...
# ...                                                  ...
# 12259  Eudes Pierre, who was shot and killed by polic...
# 12260  The fast spread of the Omicron variant has lef...
# 12261  Inyoung You, a former Boston College student w...
# 12262  Former Gov. Andrew Cuomo will not face crimina...
# 12263  The Texas Board of Pardons and Paroles has wit...
#
# [12264 rows x 2 columns]

# %%
q3_path_3 = "/Volumes/GoogleDrive/My Drive/Spring 2022/Data Science Methodology/UkraineConflictOnTwitter/DataCollection/scrapping/output/q3/May30Scrap/foxalltweets.csv"
run_sentiment_analysis_and_save(q3_path_3)
# Out:
# Removed  0 invalid tweets
# Loaded tweets at /Volumes/GoogleDrive/My Drive/Spring 2022/Data Science Methodology/UkraineConflictOnTwitter/DataCollection/scrapping/output/q3/May30Scrap/foxalltweets.csv
# Some weights of the model checkpoint at cardiffnlp/twitter-roberta-base-sentiment-latest were not used when initializing RobertaForSequenceClassification: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Running Sentiment Analysis...
# Time elapsed:  3576.2499661445618  seconds
#                             Date  \
# 0      2022-05-23 23:54:14+00:00
# 1      2022-05-23 23:52:27+00:00
# 2      2022-05-23 23:51:52+00:00
# 3      2022-05-23 23:43:17+00:00
# 4      2022-05-23 23:35:34+00:00
# ...                          ...
# 87522  2021-12-24 01:50:14+00:00
# 87523  2021-12-24 01:42:31+00:00
# 87524  2021-12-24 01:42:26+00:00
# 87525  2021-12-24 01:41:43+00:00
# 87526  2021-12-24 01:37:55+00:00
#
#                                                     text
# 0      @user Damn they sure forget the 4 years they g...
# 1      @user Inflation at 8.4% 8 trillion dollars add...
# 2      @user @user @user ENEMIES ARE WATCHING: AND TH...
# 3                   @user Russia, if you're listening...
# 4      @user Trump asked for help from Russia on LIVE...
# ...                                                  ...
# 87522  @user How dare the west try to defend a sovere...
# 87523  @user We need to give Ukraine our full militar...
# 87524  @user Putin needs to look in the mirror to poi...
# 87525  @user I'd say that the guy repeatedly threaten...
# 87526  Putin blames West for tension with Ukraine, ex...
#
# [87527 rows x 2 columns]

# %%
q3_path_4 = "/Volumes/GoogleDrive/My Drive/Spring 2022/Data Science Methodology/UkraineConflictOnTwitter/DataCollection/scrapping/output/q3/May30Scrap/nytalltweets.csv"
run_sentiment_analysis_and_save(q3_path_4)
# Out:
# Removed  0 invalid tweets
# Loaded tweets at /Volumes/GoogleDrive/My Drive/Spring 2022/Data Science Methodology/UkraineConflictOnTwitter/DataCollection/scrapping/output/q3/May30Scrap/nytalltweets.csv
# Some weights of the model checkpoint at cardiffnlp/twitter-roberta-base-sentiment-latest were not used when initializing RobertaForSequenceClassification: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Running Sentiment Analysis...
# Time elapsed:  1689.477998971939  seconds
#                             Date  \
# 0      2022-05-23 23:55:22+00:00
# 1      2022-05-23 23:53:27+00:00
# 2      2022-05-23 23:51:28+00:00
# 3      2022-05-23 23:51:24+00:00
# 4      2022-05-23 23:50:18+00:00
# ...                          ...
# 41114  2021-12-26 07:00:06+00:00
# 41115  2021-12-25 20:49:45+00:00
# 41116  2021-12-25 13:29:18+00:00
# 41117  2021-12-24 16:35:36+00:00
# 41118  2021-12-24 02:53:23+00:00
#
#                                                     text
# 0                                   @user Screw Ukraine.
# 1      @user Hunter??? Russia Russia Russia?? Clinton...
# 2      @user @user Mind you, he demeans us white peop...
# 3      @user Yeah let’s worry about this while inflat...
# 4      @user What a douche. Yeah let's 3rd world our ...
# ...                                                  ...
# 41114  Nations have chosen their leaders from among m...
# 41115  @user @user continues to promote china’s and R...
# 41116                                  @user Nazi Russia
# 41117  @user All democratic nations can halt trade wi...
# 41118  @user God damn Canadians can't get anything ri...
#
# [41119 rows x 2 columns]
